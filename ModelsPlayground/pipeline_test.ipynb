# %%
import numpy as np
import os
import uuid

# models
from scipy.optimize import curve_fit # multip. linear regression
from sklearn.svm import SVR # support vector forrest
from sklearn.ensemble import RandomForestRegressor
from sklearn.neural_network import MLPRegressor

import pandas as pd

# %%
df = pd.read_csv('aggregated_measurements_data.csv', index_col=0)

df_cleaned = df.dropna()
print("Dropped ", len(df) - len(df_cleaned), " rows with NaN values")
# Out:
# Dropped  833  rows with NaN values

# %%
# hot-reload pipeline functions from a python file
import importlib
import pipeline

importlib.reload(pipeline) # reload imported functions
# Out:
# <module 'pipeline' from 'd:\\obsidian_notes\\default_vault\\obsidian-seminar-data-science\\Media\\PrivateMedia\\data-seminar-LoRaWAN\\ModelsPlayground\\pipeline.py'>

# %%
test_specifications = [
    {
        'model': 'models/73fa15be.joblib',
    },
]

pipeline.test_models(df_cleaned, test_specifications)
# Out:
# Test 1 of 1 with id d1418ce9
# Loading model from models/73fa15be.joblib
# Fitting model RandomForestRegressor() for train size 446906
# Predicting model RandomForestRegressor() for test size 148969
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[51], line 7
#       1 test_specifications = [
#       2     {
#       3         'model': 'models/73fa15be.joblib',
#       4     },
#       5 ]
# ----> 7 pipeline.test_models(df_cleaned, test_specifications)
#
# File d:\obsidian_notes\default_vault\obsidian-seminar-data-science\Media\PrivateMedia\data-seminar-LoRaWAN\ModelsPlayground\pipeline.py:177, in test_models(data, test_specifications, stats_file)
#     175 print(f"Predicting model {model} for test size {len(x_test)}")
#     176 start_time = time.time()
# --> 177 y_pred = model.predict(x_test)
#     178 time_pred = time.time() - start_time
#     180 results.at[index, 'time_fitting'] = str(timedelta(seconds=time_fitting))
#
# File d:\Python3\lib\site-packages\sklearn\ensemble\_forest.py:1076, in ForestRegressor.predict(self, X)
#    1074 # Parallel loop
#    1075 lock = threading.Lock()
# -> 1076 Parallel(n_jobs=n_jobs, verbose=self.verbose, require="sharedmem")(
#    1077     delayed(_accumulate_prediction)(e.predict, X, [y_hat], lock)
#    1078     for e in self.estimators_
#    1079 )
#    1081 y_hat /= len(self.estimators_)
#    1083 return y_hat
#
# File d:\Python3\lib\site-packages\sklearn\utils\parallel.py:74, in Parallel.__call__(self, iterable)
#      69 config = get_config()
#      70 iterable_with_config = (
#      71     (_with_config(delayed_func, config), args, kwargs)
#      72     for delayed_func, args, kwargs in iterable
#      73 )
# ---> 74 return super().__call__(iterable_with_config)
#
# File d:\Python3\lib\site-packages\joblib\parallel.py:1918, in Parallel.__call__(self, iterable)
#    1916     output = self._get_sequential_output(iterable)
#    1917     next(output)
# -> 1918     return output if self.return_generator else list(output)
#    1920 # Let's create an ID that uniquely identifies the current call. If the
#    1921 # call is interrupted early and that the same instance is immediately
#    1922 # re-used, this id will be used to prevent workers that were
#    1923 # concurrently finalizing a task from the previous call to run the
#    1924 # callback.
#    1925 with self._lock:
#
# File d:\Python3\lib\site-packages\joblib\parallel.py:1847, in Parallel._get_sequential_output(self, iterable)
#    1845 self.n_dispatched_batches += 1
#    1846 self.n_dispatched_tasks += 1
# -> 1847 res = func(*args, **kwargs)
#    1848 self.n_completed_tasks += 1
#    1849 self.print_progress()
#
# File d:\Python3\lib\site-packages\sklearn\utils\parallel.py:136, in _FuncWrapper.__call__(self, *args, **kwargs)
#     134     config = {}
#     135 with config_context(**config):
# --> 136     return self.function(*args, **kwargs)
#
# File d:\Python3\lib\site-packages\sklearn\ensemble\_forest.py:731, in _accumulate_prediction(predict, X, out, lock)
#     724 def _accumulate_prediction(predict, X, out, lock):
#     725     """
#     726     This is a utility function for joblib's Parallel.
#     727
#     728     It can't go locally in ForestClassifier or ForestRegressor, because joblib
#     729     complains that it cannot pickle it when placed there.
#     730     """
# --> 731     prediction = predict(X, check_input=False)
#     732     with lock:
#     733         if len(out) == 1:
#
# File d:\Python3\lib\site-packages\sklearn\tree\_classes.py:530, in BaseDecisionTree.predict(self, X, check_input)
#     528 check_is_fitted(self)
#     529 X = self._validate_X_predict(X, check_input)
# --> 530 proba = self.tree_.predict(X)
#     531 n_samples = X.shape[0]
#     533 # Classification
#
# KeyboardInterrupt:
